# %%
import pandas as pd;
df = pd.read_csv('D:\Gamadata2 (no ssd)\Gamadata-Deira\gamadata-2\Full Data Garis Kemiskinan 2004 - 2024 with External Features.csv')

# %%
df
# Out:
#      Unnamed: 0        Provinsi  Tahun  Garis Kemiskinan  \
# 0             0            ACEH   2004          129615.0
# 1             1  SUMATERA UTARA   2004          122615.0
# 2             2  SUMATERA BARAT   2004          144704.0
# 3             3            RIAU   2004          179589.0
# 4             4           JAMBI   2004          129805.0
# ..          ...             ...    ...               ...
# 709         709  SULAWESI BARAT   2024          454879.0
# 710         710          MALUKU   2024          713503.0
# 711         711    MALUKU UTARA   2024          604460.0
# 712         712     PAPUA BARAT   2024          793804.0
# 713         713           PAPUA   2024          674371.0
#
#      Garis Kemiskinan Makanan Perkotaan Semester 1  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 709                                       360512.0
# 710                                       521836.0
# 711                                       475521.0
# 712                                       662195.0
# 713                                       507129.0
#
#      Garis Kemiskinan Makanan Perkotaan Semester 2  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 709                                       367828.0
# 710                                       548623.0
# 711                                       497282.0
# 712                                       679970.0
# 713                                       533022.0
#
#      Garis Kemiskinan Makanan Perdesaan Semester 1  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 709                                       350870.0
# 710                                       525301.0
# 711                                       459804.0
# 712                                       557986.0
# 713                                       404318.0
#
#      Garis Kemiskinan Makanan Perdesaan Semester 2  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 709                                       354319.0
# 710                                       533738.0
# 711                                       484025.0
# 712                                       573162.0
# 713                                       413604.0
#
#      Garis Kemiskinan Makanan Total Semester 1  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 709                                   352739.0
# 710                                   523830.0
# 711                                   464529.0
# 712                                   591923.0
# 713                                   462491.0
#
#      Garis Kemiskinan Makanan Total Semester 2  ...  Net Ekspor Triwulan II  \
# 0                                          NaN  ...                     NaN
# 1                                          NaN  ...                     NaN
# 2                                          NaN  ...                     NaN
# 3                                          NaN  ...                     NaN
# 4                                          NaN  ...                     NaN
# ..                                         ...  ...                     ...
# 709                                   356950.0  ...                 1513.06
# 710                                   540629.0  ...                -4388.17
# 711                                   487852.0  ...                 1578.01
# 712                                   609768.0  ...                11419.74
# 713                                   484209.0  ...                -6384.22
#
#      Net Ekspor Triwulan III  Net Ekspor Triwulan IV  Net Ekspor Tahunan  \
# 0                        NaN                     NaN                 NaN
# 1                        NaN                     NaN                 NaN
# 2                        NaN                     NaN                 NaN
# 3                        NaN                     NaN                 NaN
# 4                        NaN                     NaN                 NaN
# ..                       ...                     ...                 ...
# 709                  1533.84                  377.63             4594.40
# 710                 -3753.47                -5961.56           -17153.28
# 711                   222.48                 2549.04             6014.60
# 712                 12043.43                10824.70            42052.15
# 713                 -7536.75                -7689.32           -27963.63
#
#      PDRB Triwulan I  PDRB Triwulan II  PDRB Triwulan III  PDRB Triwulan IV  \
# 0                NaN               NaN                NaN               NaN
# 1                NaN               NaN                NaN               NaN
# 2                NaN               NaN                NaN               NaN
# 3                NaN               NaN                NaN               NaN
# 4                NaN               NaN                NaN               NaN
# ..               ...               ...                ...               ...
# 709         14869.16          16250.04           16197.37          16898.31
# 710         14888.16          15469.46           15953.73          16334.89
# 711         21097.87          23578.50           22513.12          28598.18
# 712         15877.08          20181.37           20234.18          19884.86
# 713         20803.90          21435.14           21500.84          22174.45
#
#      PDRB Tahunan       UMP
# 0             NaN  550000.0
# 1             NaN  537000.0
# 2             NaN  480000.0
# 3             NaN  476900.0
# 4             NaN  425000.0
# ..            ...       ...
# 709      64214.88       NaN
# 710      62646.24       NaN
# 711      95787.67       NaN
# 712      76177.48       NaN
# 713      85914.33       NaN
#
# [714 rows x 63 columns]

# %%
# create a new dataframe for the mean values
mean_df = pd.DataFrame()
# iterating from 2004 to 2024
for i in range(2004, 2025):
    # calculate the mean of the 'Garis Kemiskinan' column for the current year
    mean_value = df[df['Tahun'] == i]['Garis Kemiskinan'].mean()
    # add the mean value to the new dataframe
    mean_df[f'{i}'] = [mean_value]

# %%
mean_df
# Out:
#             2004      2005           2006           2007           2008  \
# 0  132960.419355  146443.0  163341.235294  176203.911765  205441.147059
#
#             2009           2010           2011           2012           2013  \
# 0  232477.647059  254150.382353  260232.852941  276523.205882  311572.764706
#
#    ...           2015           2016           2017           2018  \
# 0  ...  354941.911765  382382.676471  405307.441176  431887.676471
#
#             2019           2020           2021           2022           2023  \
# 0  460090.117647  492543.911765  513843.352941  550285.970588  597448.235294
#
#             2024
# 0  629839.264706
#
# [1 rows x 21 columns]

# %%
# change the structure of the dataframe to have years as rows
mean_df = mean_df.T
# reset the index to have a clean dataframe
mean_df.reset_index(inplace=True)
mean_df.columns = ['Tahun', 'Garis Kemiskinan']

# %%
mean_df
# Out:
#    Tahun  Garis Kemiskinan
# 0   2004     132960.419355
# 1   2005     146443.000000
# 2   2006     163341.235294
# 3   2007     176203.911765
# 4   2008     205441.147059
# 5   2009     232477.647059
# 6   2010     254150.382353
# 7   2011     260232.852941
# 8   2012     276523.205882
# 9   2013     311572.764706
# 10  2014     333951.500000
# 11  2015     354941.911765
# 12  2016     382382.676471
# 13  2017     405307.441176
# 14  2018     431887.676471
# 15  2019     460090.117647
# 16  2020     492543.911765
# 17  2021     513843.352941
# 18  2022     550285.970588
# 19  2023     597448.235294
# 20  2024     629839.264706

# %%
# line plot for mean_df
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(mean_df['Tahun'], mean_df['Garis Kemiskinan'], marker='o')
plt.title('Mean Garis Kemiskinan from 2004 to 2024')
plt.xlabel('Tahun')
plt.ylabel('Garis Kemiskinan')
plt.xticks(mean_df['Tahun'], rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import io
import matplotlib.pyplot as plt
import re

# The content of the file is provided in the prompt.
file_content = """
ACEH 2025 = 700196.84
ACEH 2026 = 739156.07
ACEH 2027 = 778115.31
ACEH 2028 = 817074.54
ACEH 2029 = 856140.51
SUMATERA UTARA 2025 = 670670.04
SUMATERA UTARA 2026 = 705699.24
SUMATERA UTARA 2027 = 740728.45
SUMATERA UTARA 2028 = 775757.65
SUMATERA UTARA 2029 = 810882.82
SUMATERA BARAT 2025 = 754937.48
SUMATERA BARAT 2026 = 801614.42
SUMATERA BARAT 2027 = 848291.37
SUMATERA BARAT 2028 = 894968.31
SUMATERA BARAT 2029 = 941773.14
RIAU 2025 = 739619.08
RIAU 2026 = 782516.81
RIAU 2027 = 825414.54
RIAU 2028 = 868312.27
RIAU 2029 = 911327.53
JAMBI 2025 = 691783.27
    if not line:
        continue

    # Split the line by '=' to separate the province/year from the forecast value
    parts = line.split('=')
    if len(parts) == 2:
        name_year_part = parts[0].strip()
        forecast_value = float(parts[1].strip())

        # Extract year (last 4 digits) and province name
        year = int(name_year_part[-4:])
        province_name = name_year_part[:-4].strip()

        provinces.append(province_name)
        years.append(year)
        forecasts.append(forecast_value)

# Create a DataFrame
df = pd.DataFrame({
    'Province': provinces,
    'Year': years,
    'Forecast': forecasts
})

# Calculate national forecast (mean for each year)
national_forecast = df.groupby('Year')['Forecast'].mean().reset_index()
national_forecast.rename(columns={'Forecast': 'National Average Forecast'}, inplace=True)

# Visualize each province's forecast
plt.figure(figsize=(15, 10))
for province in df['Province'].unique():
    province_data = df[df['Province'] == province]
    plt.plot(province_data['Year'], province_data['Forecast'], marker='o', label=province)

plt.title('Forecast for Each Province (2025-2029)')
plt.xlabel('Year')
plt.ylabel('Forecast Value')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.savefig('province_forecasts.png')
plt.show()

# Visualize national forecast
plt.figure(figsize=(10, 6))
plt.plot(national_forecast['Year'], national_forecast['National Average Forecast'], marker='o', color='red')
plt.title('National Average Forecast (2025-2029)')
plt.xlabel('Year')
plt.ylabel('National Average Forecast Value')
plt.grid(True)
plt.tight_layout()
plt.savefig('national_forecast.png')
plt.show()

print("Province-wise forecasts are visualized in 'province_forecasts.png'")
print("National average forecast is visualized in 'national_forecast.png'")
# Out:
# Province-wise forecasts are visualized in 'province_forecasts.png'
# National average forecast is visualized in 'national_forecast.png'

# %%
national_forecast
# Out:
#    Year  National Average Forecast
# 0  2025              665839.721176
# 1  2026              702945.685294
# 2  2027              740051.649118
# 3  2028              777157.610882
# 4  2029              814365.235588

# %%
mean_df
# Out:
#    Tahun  Garis Kemiskinan
# 0   2004     132960.419355
# 1   2005     146443.000000
# 2   2006     163341.235294
# 3   2007     176203.911765
# 4   2008     205441.147059
# 5   2009     232477.647059
# 6   2010     254150.382353
# 7   2011     260232.852941
# 8   2012     276523.205882
# 9   2013     311572.764706
# 10  2014     333951.500000
# 11  2015     354941.911765
# 12  2016     382382.676471
# 13  2017     405307.441176
# 14  2018     431887.676471
# 15  2019     460090.117647
# 16  2020     492543.911765
# 17  2021     513843.352941
# 18  2022     550285.970588
# 19  2023     597448.235294
# 20  2024     629839.264706

# %%
national_forecast.dtypes
# Out:
# Year                           int64
# National Average Forecast    float64
# dtype: object

# %%
# convert 'Tahun' to int in mean_df
mean_df['Tahun'] = mean_df['Tahun'].astype(int)

# %%
mean_df.dtypes
# Out:
# Tahun                 int64
# Garis Kemiskinan    float64
# dtype: object

# %%
import pandas as pd

# Assume mean_df and national_forecast are already defined

# Rename columns in mean_df to match national_forecast
mean_df_renamed = mean_df.rename(columns={
    "Tahun": "Year",
    "Garis Kemiskinan": "National Average Forecast"
})

# Concatenate both DataFrames
merged_df = pd.concat([mean_df_renamed, national_forecast], ignore_index=True)

# Sort by Year just in case (optional, but useful)
merged_df = merged_df.sort_values(by="Year").reset_index(drop=True)

# Show result
print(merged_df)
# Out:
#     Year  National Average Forecast
# 0   2004              132960.419355
# 1   2005              146443.000000
# 2   2006              163341.235294
# 3   2007              176203.911765
# 4   2008              205441.147059
# 5   2009              232477.647059
# 6   2010              254150.382353
# 7   2011              260232.852941
# 8   2012              276523.205882
# 9   2013              311572.764706
# 10  2014              333951.500000
# 11  2015              354941.911765
# 12  2016              382382.676471
# 13  2017              405307.441176
# 14  2018              431887.676471
# 15  2019              460090.117647
# 16  2020              492543.911765
# 17  2021              513843.352941
# 18  2022              550285.970588
# 19  2023              597448.235294
# 20  2024              629839.264706
# 21  2025              665839.721176
# 22  2026              702945.685294
# 23  2027              740051.649118
# 24  2028              777157.610882
# 25  2029              814365.235588

# %%
# Save the merged DataFrame to a CSV file
merged_df.to_csv('merged_forecasts.csv', index=False)

# %%
import matplotlib.pyplot as plt

# Split the dataframe
historical_df = merged_df[merged_df['Year'] < 2025]
forecast_df = merged_df[merged_df['Year'] >= 2025]

# Create the plot
plt.figure(figsize=(12, 6))

# Plot historical data
plt.plot(historical_df['Year'], historical_df['National Average Forecast'], label='Historical', color='blue', marker='o')
for x, y in zip(historical_df['Year'], historical_df['National Average Forecast']):
    plt.text(x, y, f'{y:,.0f}', fontsize=8, ha='center', va='bottom', color='blue')

# Plot forecast data
plt.plot(forecast_df['Year'], forecast_df['National Average Forecast'], label='Forecast', color='orange', marker='o')
for x, y in zip(forecast_df['Year'], forecast_df['National Average Forecast']):
    plt.text(x, y, f'{y:,.0f}', fontsize=8, ha='center', va='bottom', color='orange')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('National Average Forecast')
plt.title('National Average Forecast Over Time (2004–2029)')
plt.legend()
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Dibulatkan

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Apply a Seaborn style
sns.set(style="whitegrid")

# Create figure
plt.figure(figsize=(14, 7))

# Historical line
plt.plot(historical_df['Year'], historical_df['National Average Forecast'], 
         label='Historical', color='#1f77b4', linewidth=2.5, marker='o')
plt.fill_between(historical_df['Year'], historical_df['National Average Forecast'], 
                 color='#1f77b4', alpha=0.1)

# Forecast line (dashed)
plt.plot(forecast_df['Year'], forecast_df['National Average Forecast'], 
         label='Forecast', color='#ff7f0e', linewidth=2.5, linestyle='--', marker='o')
plt.fill_between(forecast_df['Year'], forecast_df['National Average Forecast'], 
                 color='#ff7f0e', alpha=0.1)

# Annotate values with 'Rp' and in 'K' (thousand)
def annotate(df, color):
    for x, y in zip(df['Year'], df['National Average Forecast']):
        y_rounded = round(y / 1000)  # Convert to thousands
        plt.text(x, y + 10000, f'Rp{y_rounded:,}K', fontsize=9, ha='center', color=color, fontweight='bold')

annotate(historical_df, '#1f77b4')
annotate(forecast_df, '#ff7f0e')

# Titles and labels
plt.title('📈 National Average Forecast (2004–2029)', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Year', fontsize=12)
plt.ylabel('National Average (Rp)', fontsize=12)
plt.xticks(historical_df['Year'].tolist() + forecast_df['Year'].tolist(), rotation=45)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)

# Style improvements
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9772\1147562520.py:40: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
